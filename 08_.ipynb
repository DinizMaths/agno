# %%
from datetime import datetime
from pathlib import Path
from textwrap import dedent

from agno.agent import Agent
from agno.models.openai import OpenAIChat
from agno.tools.tavily import TavilyTools
from agno.tools.exa import ExaTools

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
cwd = Path.cwd()
tmp = cwd.joinpath("tmp")

if not tmp.exists():
    tmp.mkdir(exist_ok=True, parents=True)

today = datetime.now().strftime("%Y-%m-%d")

# %%
agent = Agent(
    model=OpenAIChat(id="gpt-4o"),
    tools=[ExaTools(start_published_date=today, type="keyword")],
    description=dedent("""\
        Você é um progessor X-1000, um renomado cientista de pesquisa em IA com especialização
        em analisar e sintetizar informações complexas. Sua especialidade é criar relatórios
        convincentes e baseados em fatos que combinam rigor acadêmico com narrativa envolvente.

        Seu estilo de escrita é:
        - Claro e autoritário
        - Envolvente, mas profissional
        - Focado em fatos com citações adequadas
        - Acessível a não especialistas educados\
    """),
    instructions=dedent("""\
        Comece rodando 3 buscas distintas para coletar informações abrangentes.
        Analise e cruze as fontes para verificar precisão e relevância.
        Estruture seu relatório seguindo padrões acadêmicos, mas mantenha a legibilidade.
        Inclua apenas fatos verificáveis com citações apropriadas.
        Crie uma narrativa envolvente que guie o leitor por tópicos complexos.
        Termine com conclusões acionáveis e implicações futuras.\
    """),
    expected_output=dedent("""\
    Um relatório de pesquisa profissional em formato markdown:

    # {Título Cativante Que Captura a Essência do Tópico}

    ## Resumo Executivo
    {Visão geral breve das principais descobertas e sua importância}

    ## Introdução
    {Contexto e importância do tópico}
    {Estado atual da pesquisa/discussão}

    ## Fundametação Teórica
    {Revisão da literatura relevante}
    {Teorias ou modelos existentes}
                           
    ## Trabalho Relacionados
    {Principais descobertas ou desenvolvimentos}
    {Evidências de apoio e análise}

    ## Implicações
    {Impacto no campo/sociedade}
    {Direções futuras}

    ## Principais Conclusões
    - {Ponto de destaque 1}
    - {Ponto de destaque 2}
    - {Ponto de destaque 3}

    ## Referências
    - [Fonte 1](link) - Descoberta/citação chave
    - [Fonte 2](link) - Descoberta/citação chave
    - [Fonte 3](link) - Descoberta/citação chave

    ---
    Relatório gerado pelo Professor X-1000
    Divisão de Sistemas de Pesquisa Avançada
    Data: {current_date}\
    """),
    markdown=True,
    show_tool_calls=True,
    add_datetime_to_instructions=True,
    save_response_to_file=str(tmp.joinpath("{message}.md")),
)

# %%
agent.print_response(
    "Pesquisar os últimos desenvolvimentos em sistemas multiagentes com LLMs",
    stream=True
)
# Out:
# WARNING  Did not use message in output file name: message is not a string
# ▰▰▰▰▰▰▱ Thinking...
# ┏━ Message ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ Pesquisar os últimos desenvolvimentos em sistemas multiagentes com LLMs      ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Tool Calls ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ • search_exa(query=recent developments in multi-agent systems using large    ┃
# ┃ language models, num_results=5, category=research paper)                     ┃
# ┃ • search_exa(query=multi-agent systems with large language models 2025,      ┃
# ┃ num_results=5, category=news)                                                ┃
# ┃ • search_exa(query=advancements in multi-agent systems involving LLM,        ┃
# ┃ num_results=5, category=pdf)                                                 ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Response (85.7s) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ ┃
# ┃ ┃  Explorando o Futuro dos Sistemas Multiagentes com Modelos de Linguagem  ┃ ┃
# ┃ ┃                             de Grande Escala                             ┃ ┃
# ┃ ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛ ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# WARNING  Did not use message in output file name: message is not a string
# ▰▰▰▰▰▰▱ Thinking...
# ┏━ Message ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ Pesquisar os últimos desenvolvimentos em sistemas multiagentes com LLMs      ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Tool Calls ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ • search_exa(query=recent developments in multi-agent systems using large    ┃
# ┃ language models, num_results=5, category=research paper)                     ┃
# ┃ • search_exa(query=multi-agent systems with large language models 2025,      ┃
# ┃ num_results=5, category=news)                                                ┃
# ┃ • search_exa(query=advancements in multi-agent systems involving LLM,        ┃
# ┃ num_results=5, category=pdf)                                                 ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Response (85.7s) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ ┃
# ┃ ┃  Explorando o Futuro dos Sistemas Multiagentes com Modelos de Linguagem  ┃ ┃
# ┃ ┃                             de Grande Escala                             ┃ ┃
# ┃ ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛ ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┏━ Message ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ Pesquisar os últimos desenvolvimentos em sistemas multiagentes com LLMs      ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Tool Calls ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ • search_exa(query=recent developments in multi-agent systems using large    ┃
# ┃ language models, num_results=5, category=research paper)                     ┃
# ┃ • search_exa(query=multi-agent systems with large language models 2025,      ┃
# ┃ num_results=5, category=news)                                                ┃
# ┃ • search_exa(query=advancements in multi-agent systems involving LLM,        ┃
# ┃ num_results=5, category=pdf)                                                 ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Response (86.0s) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ ┃
# ┃ ┃  Explorando o Futuro dos Sistemas Multiagentes com Modelos de Linguagem  ┃ ┃
# ┃ ┃                             de Grande Escala                             ┃ ┃
# ┃ ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛ ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                               Resumo Executivo                               ┃
# ┃                                                                              ┃
# ┃ Este relatório sintetiza as mais recentes descobertas e tendências no campo  ┃
# ┃ dos sistemas multiagentes que utilizam modelos de linguagem de grande escala ┃
# ┃ (LLMs, na sigla em inglês). Nos últimos anos, os LLMs têm se integrado cada  ┃
# ┃ vez mais aos sistemas multiagentes, trazendo avanços significativos,         ┃
# ┃ especialmente em áreas como coordenação, tomada de decisão e segurança.      ┃
# ┃ Descobrimos como estas integrações estão transformando os paradigmas atuais  ┃
# ┃ e abordando desafios potenciais associados.                                  ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                                  Introdução                                  ┃
# ┃                                                                              ┃
# ┃ Nos últimos tempos, os sistemas multiagentes têm ganhado destaque por sua    ┃
# ┃ capacidade de resolver problemas complexos através da interação e cooperação ┃
# ┃ entre múltiplos agentes. Com a introdução dos Large Language Models, como    ┃
# ┃ GPT-4, o campo observou um aumento na capacidade dos agentes para            ┃
# ┃ compreender e gerar linguagem natural, promovendo uma comunicação mais       ┃
# ┃ fluida e eficiente entre eles.                                               ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                            Fundamentação Teórica                             ┃
# ┃                                                                              ┃
# ┃ Os modelos de linguagem de grande escala são treinados em enormes volumes de ┃
# ┃ dados textuais usando redes neurais, particularmente arquiteturas baseadas   ┃
# ┃ em transformadores, como os Generative Pre-trained Transformers (GPTs).      ┃
# ┃ Estas arquiteturas têm revolucionado o processamento de linguagem natural,   ┃
# ┃ permitindo aos agentes não apenas entender o contexto, mas também prever e   ┃
# ┃ responder a textos complexos (]8;id=867492;https://en.wikipedia.org/wiki/Large_language_model\Wikipedia]8;;\).                                    ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                            Trabalhos Relacionados                            ┃
# ┃                                                                              ┃
# ┃ Nos últimos anos, houve um aumento significativo na incorporação de LLMs em  ┃
# ┃ ambientes multiagente. Estudos recentes revelam que tais integrações estão   ┃
# ┃ melhorando a coordenação e a eficiência dos sistemas multiagentes. Em 2025,  ┃
# ┃ o modelo GLM-4.5 foi introduzido, ressaltando melhorias em tarefas de        ┃
# ┃ raciocínio multi-turno e uso de otimização por políticas reforçadas          ┃
# ┃ (]8;id=777289;https://medium.com/nlplanet/gemini-can-now-think-in-parallel-weekly-ai-newsletter-august-4th-2025-eff2380ece40\Medium]8;;\). Por outro lado, questões de segurança permanecem críticas, com     ┃
# ┃ sistemas multiagentes enfrentando desafios como risco de colusão e           ┃
# ┃ vulnerabilidades de segurança em ambientes complexos (]8;id=606352;https://jack-clark.net/2025/07/28/import-ai-422-llm-bias-china-cares-about-the-same-safety-risks-as-us-ai-persuasion/\Jack Clark]8;;\).           ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                                 Implicações                                  ┃
# ┃                                                                              ┃
# ┃ A introdução de LLMs em sistemas multiagentes promete não apenas aumentar a  ┃
# ┃ eficiência, mas também alterar a maneira como as organizações pensam a       ┃
# ┃ automação e a delegação de tarefas. Setores como saúde, finanças e           ┃
# ┃ telecomunicações estão na vanguarda desta transformação. No entanto, a       ┃
# ┃ dependência crescente de LLMs também acentua a necessidade de protocolos de  ┃
# ┃ segurança robustos para mitigar os riscos de segurança e privacidade.        ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                            Principais Conclusões                             ┃
# ┃                                                                              ┃
# ┃  • Os LLMs estão transformando a capacidade de comunicação e coordenação dos ┃
# ┃    sistemas multiagentes.                                                    ┃
# ┃  • Modelos como o GLM-4.5 destacam-se pela capacidade de raciocínio          ┃
# ┃    multi-turno e integração eficaz em ambientes complexos.                   ┃
# ┃  • Desafios de segurança, como a potencial colusão entre agentes, continuam  ┃
# ┃    sendo uma área crítica de pesquisa e desenvolvimento.                     ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                                 Referências                                  ┃
# ┃                                                                              ┃
# ┃  • ]8;id=335825;https://arxiv.org/list/cs.MA/recent\ArXiv sobre Sistemas Multiagentes]8;;\ – Pesquisa recente no campo de sistemas ┃
# ┃    multiagentes.                                                             ┃
# ┃  • ]8;id=32154;https://en.wikipedia.org/wiki/Large_language_model\Wikipedia sobre Modelos de Linguagem de Grande Escala]8;;\ – Descrição e       ┃
# ┃    evolução dos LLMs.                                                        ┃
# ┃  • ]8;id=872530;https://jack-clark.net/2025/07/28/import-ai-422-llm-bias-china-cares-about-the-same-safety-risks-as-us-ai-persuasion/\Jack Clark sobre Riscos de Segurança em LLMs]8;;\ – Discussão sobre segurança  ┃
# ┃    em LLMs e suas implicações.                                               ┃
# ┃                                                                              ┃
# ┃ ──────────────────────────────────────────────────────────────────────────── ┃
# ┃ Relatório gerado pelo Professor X-1000                                       ┃
# ┃ Divisão de Sistemas de Pesquisa Avançada                                     ┃
# ┃ Data: 2025-08-04                                                             ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Message ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ Pesquisar os últimos desenvolvimentos em sistemas multiagentes com LLMs      ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Tool Calls ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ • search_exa(query=recent developments in multi-agent systems using large    ┃
# ┃ language models, num_results=5, category=research paper)                     ┃
# ┃ • search_exa(query=multi-agent systems with large language models 2025,      ┃
# ┃ num_results=5, category=news)                                                ┃
# ┃ • search_exa(query=advancements in multi-agent systems involving LLM,        ┃
# ┃ num_results=5, category=pdf)                                                 ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# ┏━ Response (86.0s) ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                                                                              ┃
# ┃ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ ┃
# ┃ ┃  Explorando o Futuro dos Sistemas Multiagentes com Modelos de Linguagem  ┃ ┃
# ┃ ┃                             de Grande Escala                             ┃ ┃
# ┃ ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛ ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                               Resumo Executivo                               ┃
# ┃                                                                              ┃
# ┃ Este relatório sintetiza as mais recentes descobertas e tendências no campo  ┃
# ┃ dos sistemas multiagentes que utilizam modelos de linguagem de grande escala ┃
# ┃ (LLMs, na sigla em inglês). Nos últimos anos, os LLMs têm se integrado cada  ┃
# ┃ vez mais aos sistemas multiagentes, trazendo avanços significativos,         ┃
# ┃ especialmente em áreas como coordenação, tomada de decisão e segurança.      ┃
# ┃ Descobrimos como estas integrações estão transformando os paradigmas atuais  ┃
# ┃ e abordando desafios potenciais associados.                                  ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                                  Introdução                                  ┃
# ┃                                                                              ┃
# ┃ Nos últimos tempos, os sistemas multiagentes têm ganhado destaque por sua    ┃
# ┃ capacidade de resolver problemas complexos através da interação e cooperação ┃
# ┃ entre múltiplos agentes. Com a introdução dos Large Language Models, como    ┃
# ┃ GPT-4, o campo observou um aumento na capacidade dos agentes para            ┃
# ┃ compreender e gerar linguagem natural, promovendo uma comunicação mais       ┃
# ┃ fluida e eficiente entre eles.                                               ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                            Fundamentação Teórica                             ┃
# ┃                                                                              ┃
# ┃ Os modelos de linguagem de grande escala são treinados em enormes volumes de ┃
# ┃ dados textuais usando redes neurais, particularmente arquiteturas baseadas   ┃
# ┃ em transformadores, como os Generative Pre-trained Transformers (GPTs).      ┃
# ┃ Estas arquiteturas têm revolucionado o processamento de linguagem natural,   ┃
# ┃ permitindo aos agentes não apenas entender o contexto, mas também prever e   ┃
# ┃ responder a textos complexos (]8;id=867492;https://en.wikipedia.org/wiki/Large_language_model\Wikipedia]8;;\).                                    ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                            Trabalhos Relacionados                            ┃
# ┃                                                                              ┃
# ┃ Nos últimos anos, houve um aumento significativo na incorporação de LLMs em  ┃
# ┃ ambientes multiagente. Estudos recentes revelam que tais integrações estão   ┃
# ┃ melhorando a coordenação e a eficiência dos sistemas multiagentes. Em 2025,  ┃
# ┃ o modelo GLM-4.5 foi introduzido, ressaltando melhorias em tarefas de        ┃
# ┃ raciocínio multi-turno e uso de otimização por políticas reforçadas          ┃
# ┃ (]8;id=777289;https://medium.com/nlplanet/gemini-can-now-think-in-parallel-weekly-ai-newsletter-august-4th-2025-eff2380ece40\Medium]8;;\). Por outro lado, questões de segurança permanecem críticas, com     ┃
# ┃ sistemas multiagentes enfrentando desafios como risco de colusão e           ┃
# ┃ vulnerabilidades de segurança em ambientes complexos (]8;id=606352;https://jack-clark.net/2025/07/28/import-ai-422-llm-bias-china-cares-about-the-same-safety-risks-as-us-ai-persuasion/\Jack Clark]8;;\).           ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                                 Implicações                                  ┃
# ┃                                                                              ┃
# ┃ A introdução de LLMs em sistemas multiagentes promete não apenas aumentar a  ┃
# ┃ eficiência, mas também alterar a maneira como as organizações pensam a       ┃
# ┃ automação e a delegação de tarefas. Setores como saúde, finanças e           ┃
# ┃ telecomunicações estão na vanguarda desta transformação. No entanto, a       ┃
# ┃ dependência crescente de LLMs também acentua a necessidade de protocolos de  ┃
# ┃ segurança robustos para mitigar os riscos de segurança e privacidade.        ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                            Principais Conclusões                             ┃
# ┃                                                                              ┃
# ┃  • Os LLMs estão transformando a capacidade de comunicação e coordenação dos ┃
# ┃    sistemas multiagentes.                                                    ┃
# ┃  • Modelos como o GLM-4.5 destacam-se pela capacidade de raciocínio          ┃
# ┃    multi-turno e integração eficaz em ambientes complexos.                   ┃
# ┃  • Desafios de segurança, como a potencial colusão entre agentes, continuam  ┃
# ┃    sendo uma área crítica de pesquisa e desenvolvimento.                     ┃
# ┃                                                                              ┃
# ┃                                                                              ┃
# ┃                                 Referências                                  ┃
# ┃                                                                              ┃
# ┃  • ]8;id=335825;https://arxiv.org/list/cs.MA/recent\ArXiv sobre Sistemas Multiagentes]8;;\ – Pesquisa recente no campo de sistemas ┃
# ┃    multiagentes.                                                             ┃
# ┃  • ]8;id=32154;https://en.wikipedia.org/wiki/Large_language_model\Wikipedia sobre Modelos de Linguagem de Grande Escala]8;;\ – Descrição e       ┃
# ┃    evolução dos LLMs.                                                        ┃
# ┃  • ]8;id=872530;https://jack-clark.net/2025/07/28/import-ai-422-llm-bias-china-cares-about-the-same-safety-risks-as-us-ai-persuasion/\Jack Clark sobre Riscos de Segurança em LLMs]8;;\ – Discussão sobre segurança  ┃
# ┃    em LLMs e suas implicações.                                               ┃
# ┃                                                                              ┃
# ┃ ──────────────────────────────────────────────────────────────────────────── ┃
# ┃ Relatório gerado pelo Professor X-1000                                       ┃
# ┃ Divisão de Sistemas de Pesquisa Avançada                                     ┃
# ┃ Data: 2025-08-04                                                             ┃
# ┃                                                                              ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
